# %% [markdown]
# # Tasks 1- 4

# %% [markdown]
# These are my solutions to the Tasks assignments 1-4. The author of this jupyter nootebook is Kevin Flanagan (G00228079@gmit.ie).

# %% [markdown]
# ### Task 1:Calculate a square root
# ***
# We can calculate the square root of a number using Newton's method [1,2].
# To find the square root $z$ of a number $x$, we can iterate using the following equation.
#
# $$ z_{next} = z - \frac{z^2 - x} {2z} $$
#
# [1] A Tour of Go; Exercise: Loops and Funtions; https://tour.golang.org/flowcontrol/8
#
# [2] Newton's method; https://en.wikipedia.org/wiki/Newton%27s_method
#
# This task is to find out the square root of 2 and explain how to calculate that with out importing $Math$ into
# the program. There are loads of examples online to help with this problem, but it must be explained how we completed this task.
# My research has me looking at $wiki$ to $stackoverflow$ for the answers.
# From my research i discovered the (** power operator). the power operator submits its left argument to the power of the right argument. This way the numbers are first converted to a common type to be used with one another.
#
#
# [3] Square root from Codecademy; I found $Codecademy$ to be a very helpful in explaining how this works. https://www.codecademy.com/forum_questions/50ee2c132f1af5aa76000c7f
# This only showed me how the power operator worked and i still need to print out to 100 decimals.
#
# For this problem more research was needed, some of the best examples i found were as follows:
# [4] $Reddit$ https://amp.reddit.com/r/AskProgramming/comments/j8mwxr/how_to_get_the_square_root_of_a_number_to_100/
#
# and
#
# [5] $StackOverFlow$ https://stackoverflow.com/questions/4733173/how-can-i-show-an-irrational-number-to-100-decimal-places-in-python

# %%
def sqrt(x):
    """
    A funtion to calculate the square root of a number x. 
    """
    # Initial guess for the square root z.
    z = x / 2
    #Loopn until we're happy with the accuracy.
    while abs(x - (z * z)) > 0.001:
        # Calculate a better guess for the square root.
        z -= (z*z -x) / (2 * z)
    # Return the (approximate) square root of x.     
    return z

# %% [markdown]
# #### Tests of the function
#
# Here we test the function with some known values.

# %%
# Test the function on 100.

sqrt(100)
# Out:
# 10.000046356507898

# %%
# Test the function on 2.
sqrt(2)
# Out:
# 1.4142156862745099

# %%
# Showing sqrt of 2 to 100 decimal places TASK 1
# I use "input" to recieve the number from the user 
num = int(input("Enter number here: "))
# ** power operator must use (.5)... (1/2) will not work
sqrt = num**0.5
#prints out the result... "%.100f" is telling the program to print out up to 100 decimal places
print("The square root of ",num, "is","%.100f" % sqrt)

# %% [markdown]
# ### End

# %% [markdown]
# ### Task 2:Chi-Square or $ X^2 $

# %% [markdown]
# Chi-square which can also be displayed as $ X^2 $ is a test that measures how a model compares to data that has been observed. This data is better if it is raw data coming from independent variables from a wide sourse of samples. Chi-square compares the difference between raw data and what the expected result from the data will be. Chi-square can be used to validate data of whats expected and whats achieved.

# %%
import scipy.stats as stats
catergories=[[90,60,104,95],[30,50,51,20],[30,40,45,35,]]
total = chi2,p,dof,exp=stats.chi2_contingency(catergories)
print(chi2)
print(p)

# %% [markdown]
# ### End

# %% [markdown]
# ### Task 3: STDEV.P vs STDEV.S

# %% [markdown]
# The standard deviation $STDEV.P$ and $STDEV.S$
#
# $STDEVP$ assumes that this is the entire population where $STDEV.S$ represents a sample of the population. STDEV.S deals with smaller sample numbers then the STDEV.P which deals with numbers that are alot bigger. These test work in a way that if a very small sample is tested a large difference can be seen form the tests.
# My understanding of the stdev.p and stdev.s is that the "p" takes the whole population data set (all the elements) and works out the true mean. Where the "s" takes a sample of the of the data set and works out the mean. STDEV.S uses the $n-1$ for it formulas where STDEV.P uses $n$ for its formulas

# %% [markdown]
# This first image shows the Population example! ![POP.PNG](attachment:POP.PNG)
#
#
# This second image shows a sample of the population of the data! ![Sample.PNG](attachment:Sample.PNG)

# %% [markdown]
# This is an image of the formulas that are used showing the difference between stdev.p and stdev.s
# ![fomulas.PNG](attachment:fomulas.PNG)

# %% [markdown]
# Excels STDEV.S which calculates the $Sample$ standard deviation, where Numpys STDEV.P calculates the $Population$ by default. The reason for this is that numpy uses a different equation to work out the standard deviation.When working out the difference beteween the sample and population standard deviation is that sample uses $ N-1 $ where population uses $N$. This is known as one degree of freedom, the user subtracts 1 in order to get an unbiased estimator of the results.

# %% [markdown]
# ### End

# %% [markdown]
# ### Task 4: kNN (k Nearest Neighbours)

# %% [markdown]
# $kNN$ or K-nearest neighbours. This is one of the simplest classification algorithms and is one of the most used learning algorithms. This algorithm is used to get data points from different data classes and this will help make a new classification of a sample point.

# %% [markdown]
# The Iris flower data set is a multivariate data set introduced by Ronald Fisher in 1936 as an axample of discriminant analysis. The same Ronald Fisher who invented Fishers exact test. The discriminant function is used on $Iris Versicolor$ and $Iris Virginica$ but the $Iris Setosa$ is different from the other two species.

# %% [markdown]
# ![Iris.PNG](attachment:Iris.PNG)

# %% [markdown]
# kNN - https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75

# %% [markdown]
# ## End
